# %%
import pandas as pd
import numpy as np

# %%
#Loading data
df1=pd.read_csv('admission test.csv')
df1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  NaN   3.5  8.00
# 3             4        322          110                  3  NaN   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df1.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  NaN   3.5  8.00
# 3           4        322          110                  3  NaN   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df1.head(20)
# Out:
#     Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0            1        337          118                  4  4.5   4.5  9.65
# 1            2        324          107                  4  4.0   4.5  8.87
# 2            3        316          104                  3  NaN   3.5  8.00
# 3            4        322          110                  3  NaN   2.5  8.67
# 4            5        314          103                  2  2.0   3.0  8.21
# 5            6        330          115                  5  4.5   3.0  9.34
# 6            7        321          109                  3  3.0   4.0  8.20
# 7            8        308          101                  2  3.0   4.0  7.90
# 8            9        302          102                  1  2.0   1.5  8.00
# 9           10        323          108                  3  3.5   3.0  8.60
# 10          11        325          106                  3  3.5   4.0  8.40
# ...

# %%
df1.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
df1.tail(20)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 380         381        322          104                  3  3.5   4.0  8.84
# 381         382        319          105                  3  3.0   3.5  8.67
# 382         383        324          110                  4  4.5   4.0  9.15
# 383         384        300          100                  3  3.0   3.5  8.26
# 384         385        340          113                  4  5.0   5.0  9.74
# 385         386        335          117                  5  5.0   5.0  9.82
# 386         387        302          101                  2  2.5   3.5  7.96
# 387         388        307          105                  2  2.0   3.5  8.10
# 388         389        296           97                  2  1.5   2.0  7.80
# 389         390        320          108                  3  3.5   4.0  8.44
# 390         391        314          102                  2  2.0   2.5  8.24
# ...

# %%
df1.shape
# Out:
# (400, 9)

# %%
df1.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
df1['GRE Score']
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
#       ...
# 395    324
# 396    325
# 397    330
# 398    312
# 399    333
# Name: GRE Score, Length: 400, dtype: int64

# %%
df1['GRE Score'].max()
# Out:
# 340

# %%
df1['GRE Score'].min()
# Out:
# 290

# %%
df1['GRE Score'].mean()
# Out:
# 316.8075

# %%
for i in df1['GRE Score']:
    print(i)
# Out:
# 337
# 324
# 316
# 322
# 314
# 330
# 321
# 308
# 302
# 323
# 325
# 327
# 328
# 307
# 311
# 314
# 317
# 319
# 318
# 303
# 312
# 325
# 328
# 334
# 336
# 340
# 322
# 298
# 295
# 310
# 300
# 327
# 338
# 340
# 331
# 320
# 299
# 300
# 304
# 307
# 308
# 316
# 313
# 332
# 326
# 322
# 329
# 339
# 321
# 327
# 313
# 312
# 334
# 324
# 322
# 320
# 316
# 298
# 300
# 311
# 309
# 307
# 304
# 315
# 325
# 325
# 327
# 316
# 318
# 328
# 332
# 336
# 321
# 314
# 314
# 329
# 327
# 301
# 296
# 294
# 312
# 340
# 320
# 322
# 340
# 319
# 315
# 317
# 314
# 316
# 318
# 299
# 298
# 301
# 303
# 304
# 306
# 331
# 332
# 323
# 322
# 312
# 314
# 317
# 326
# 316
# 329
# 338
# 331
# 304
# 305
# 321
# 301
# 320
# 311
# 310
# 299
# 290
# 296
# 327
# 335
# 334
# 310
# 308
# 301
# 300
# 323
# 319
# 326
# 333
# 339
# 303
# 309
# 323
# 333
# 314
# 312
# 316
# 326
# 318
# 329
# 332
# 331
# 340
# 325
# 320
# 315
# 326
# 339
# 311
# 334
# 332
# 321
# 324
# 326
# 312
# 315
# 309
# 306
# 297
# 315
# 298
# 318
# 317
# 329
# 322
# ...

# %%
for i in df1['GRE Score']:
    if(i>310):
        print(i)
# Out:
# 337
# 324
# 316
# 322
# 314
# 330
# 321
# 323
# 325
# 327
# 328
# 311
# 314
# 317
# 319
# 318
# 312
# 325
# 328
# 334
# 336
# 340
# 322
# 327
# 338
# 340
# 331
# 320
# 316
# 313
# 332
# 326
# 322
# 329
# 339
# 321
# 327
# 313
# 312
# 334
# 324
# 322
# 320
# 316
# 311
# 315
# 325
# 325
# 327
# 316
# 318
# 328
# 332
# 336
# 321
# 314
# 314
# 329
# 327
# 312
# 340
# 320
# 322
# 340
# 319
# 315
# 317
# 314
# 316
# 318
# 331
# 332
# 323
# 322
# 312
# 314
# 317
# 326
# 316
# 329
# 338
# 331
# 321
# 320
# 311
# 327
# 335
# 334
# 323
# 319
# 326
# 333
# 339
# 323
# 333
# 314
# 312
# 316
# 326
# 318
# 329
# 332
# 331
# 340
# 325
# 320
# 315
# 326
# 339
# 311
# 334
# 332
# 321
# 324
# 326
# 312
# 315
# 315
# 318
# 317
# 329
# 322
# 313
# 311
# 312
# 334
# 322
# 323
# 321
# 320
# 329
# 319
# 314
# 316
# 327
# 317
# 335
# 331
# 324
# 324
# 323
# 322
# 336
# 316
# 311
# 313
# 317
# 315
# 340
# 334
# 315
# 325
# 328
# 338
# 333
# 331
# 330
# 322
# 321
# 324
# 312
# 313
# 316
# 324
# 312
# 318
# ...

# %%
df1[5:6]
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 5           6        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit
# 5         1               0.9

# %%
df1[5:24]
# Out:
#     Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 5            6        330          115                  5  4.5   3.0  9.34
# 6            7        321          109                  3  3.0   4.0  8.20
# 7            8        308          101                  2  3.0   4.0  7.90
# 8            9        302          102                  1  2.0   1.5  8.00
# 9           10        323          108                  3  3.5   3.0  8.60
# 10          11        325          106                  3  3.5   4.0  8.40
# 11          12        327          111                  4  4.0   4.5  9.00
# 12          13        328          112                  4  4.0   4.5  9.10
# 13          14        307          109                  3  4.0   3.0  8.00
# 14          15        311          104                  3  3.5   2.0  8.20
# 15          16        314          105                  3  3.5   2.5  8.30
# ...

# %%
df1[5:16].max()
# Out:
# Serial No.            16.00
# GRE Score            330.00
# TOEFL Score          115.00
# University Rating      5.00
# SOP                    4.50
# LOR                    4.50
# CGPA                   9.34
# Research               1.00
# Chance of Admit        0.90
# dtype: float64

# %%
df1[5:21].min()
# Out:
# Serial No.             6.00
# GRE Score            302.00
# TOEFL Score          101.00
# University Rating      1.00
# SOP                    2.00
# LOR                    1.50
# CGPA                   7.90
# Research               0.00
# Chance of Admit        0.45
# dtype: float64

# %%
df1['TOEFL Score'][6: 7]
# Out:
# 6    109
# Name: TOEFL Score, dtype: int64

# %%
df1['TOEFL Score'][6: 17]
# Out:
# 6     109
# 7     101
# 8     102
# 9     108
# 10    106
# 11    111
# 12    112
# 13    109
# 14    104
# 15    105
# 16    107
# Name: TOEFL Score, dtype: int64

# %%
df2=df1[['TOEFL Score','GRE Score','Chance of Admit ']]
print(df2)

# %%
df2.to_csv('score.csv')# extraction or export
df2.to_html('score.html')

# %%
df1.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  398.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400754
# std    115.614301   11.473646     6.069514           1.143728    1.009189
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df1.isnull()# missing values
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating    SOP   LOR   \
# 0         False      False        False              False  False  False
# 1         False      False        False              False  False  False
# 2         False      False        False              False   True  False
# 3         False      False        False              False   True  False
# 4         False      False        False              False  False  False
# ..          ...        ...          ...                ...    ...    ...
# 395       False      False        False              False  False  False
# 396       False      False        False              False  False  False
# 397       False      False        False              False  False  False
# 398       False      False        False              False  False  False
# 399       False      False        False              False  False  False
#
#       CGPA  Research  Chance of Admit
# 0    False     False             False
# ...

# %%
df1.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  2
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df1=df1.fillna(df1['SOP'].mean())
df1# to fill the mean value
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating       SOP  LOR   \
# 0             1        337          118                  4  4.500000   4.5
# 1             2        324          107                  4  4.000000   4.5
# 2             3        316          104                  3  3.400754   3.5
# 3             4        322          110                  3  3.400754   2.5
# 4             5        314          103                  2  2.000000   3.0
# ..          ...        ...          ...                ...       ...   ...
# 395         396        324          110                  3  3.500000   3.5
# 396         397        325          107                  3  3.000000   3.5
# 397         398        330          116                  4  5.000000   4.5
# 398         399        312          103                  3  3.500000   4.0
# 399         400        333          117                  4  5.000000   4.0
#
#      CGPA  Research  Chance of Admit
# ...

# %%
df1['SOP'].fillna(df1['SOP'].mean())#
df1['GRE Score'].fillna(df1['GRE Score'].mean())
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
#       ...
# 395    324
# 396    325
# 397    330
# 398    312
# 399    333
# Name: GRE Score, Length: 400, dtype: int64

# %%
df1.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(df1['GRE Score'],df1['Chance of Admit '])
plt.xlabel('GRE score')
plt.grid()
plt.ylabel('Admission chances')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(df1['GRE Score'],df1['Chance of Admit '])
plt.xlabel('GRE score')
plt.grid()
plt.ylabel('Admission chances')
plt.show()

# %%
plt.boxplot(df1['GRE Score'])# checking for outliers
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9c8c7aa190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9c8c7aa850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9c8c704df0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9c8c7aaf10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9c8c785250>],
#  'means': []}

# %%
plt.boxplot([df1['GRE Score'],df1['TOEFL Score']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9c8ce0a910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9c8ce0afd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9c8ce0a5b0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f9c8ce166d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9c8ce169d0>,
# ...
#  'means': []}
