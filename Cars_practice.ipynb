# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.head() # it will print top 5 rows
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=301, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
# Car_Name         301 non-null object
# Year             301 non-null int64
# Selling_Price    301 non-null float64
# Present_Price    301 non-null float64
# Kms_Driven       301 non-null int64
# Fuel_Type        301 non-null object
# Seller_Type      301 non-null object
# Transmission     301 non-null object
# Owner            301 non-null int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
#Indexing and slicing 
df[250:251] #Indexing
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 250    creta  2016           12.9           13.6       35934    Diesel
#
#     Seller_Type Transmission  Owner
# 250      Dealer       Manual      0

# %%
df[101:125] #slicing
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 101         UM Renegade Mojave  2017           1.70           1.82
# 102                  KTM RC200  2017           1.65           1.78
# 103          Bajaj Dominar 400  2017           1.45           1.60
# 104  Royal Enfield Classic 350  2017           1.35           1.47
# 105                  KTM RC390  2015           1.35           2.37
# 106             Hyosung GT250R  2014           1.35           3.45
# 107  Royal Enfield Thunder 350  2013           1.25           1.50
# 108  Royal Enfield Thunder 350  2016           1.20           1.50
# 109  Royal Enfield Classic 350  2017           1.20           1.47
# 110                  KTM RC200  2016           1.20           1.78
# 111  Royal Enfield Thunder 350  2016           1.15           1.50
# 112              KTM 390 Duke   2014           1.15           2.40
# 113        Mahindra Mojo XT300  2016           1.15           1.40
# ...

# %%
df[['Car_Name','Present_Price', 'Year']]
# Out:
#     Car_Name  Present_Price  Year
# 0       ritz           5.59  2014
# 1        sx4           9.54  2013
# 2       ciaz           9.85  2017
# 3    wagon r           4.15  2011
# 4      swift           6.87  2014
# ..       ...            ...   ...
# 296     city          11.60  2016
# 297     brio           5.90  2015
# 298     city          11.00  2009
# 299     city          12.50  2017
# 300     brio           5.90  2016
#
# [301 rows x 3 columns]

# %%
df['Year'].max()
# Out:
# 2018

# %%
df['Year'].min()
# Out:
# 2003

# %%
df.max()
# Out:
# Car_Name              xcent
# Year                   2018
# Selling_Price            35
# Present_Price          92.6
# Kms_Driven           500000
# Fuel_Type            Petrol
# Seller_Type      Individual
# Transmission         Manual
# Owner                     3
# dtype: object

# %%
df.min()
# Out:
# Car_Name               800
# Year                  2003
# Selling_Price          0.1
# Present_Price         0.32
# Kms_Driven             500
# Fuel_Type              CNG
# Seller_Type         Dealer
# Transmission     Automatic
# Owner                    0
# dtype: object

# %%
df['Selling_Price'].mean()
# Out:
# 4.661295681063127

# %%
df['Selling_Price'].std()
# Out:
# 5.082811556177804

# %%
search = input('Enter the car name: ')
for i in df['Car_Name']:
    if (i ==search):
        print (i)
# Out:
# Enter the car name: Bajaj Pulsar RS200
# Bajaj Pulsar RS200

# %%
df[df['Car_Name']== 'Royal Enfield Thunder 350']
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 107  Royal Enfield Thunder 350  2013           1.25            1.5
# 108  Royal Enfield Thunder 350  2016           1.20            1.5
# 111  Royal Enfield Thunder 350  2016           1.15            1.5
# 121  Royal Enfield Thunder 350  2011           1.05            1.5
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 107       15000    Petrol  Individual       Manual      0
# 108       18000    Petrol  Individual       Manual      0
# 111        8700    Petrol  Individual       Manual      0
# 121        6900    Petrol  Individual       Manual      0

# %%
df_2016 = df[df['Year']== 2016]
df_2016
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 8                         ciaz  2016           8.75           8.89
# 15                      ertiga  2016           7.75          10.79
# 17                      ertiga  2016           7.75          10.79
# 20                    alto k10  2016           2.85           3.95
# 38                    alto k10  2016           3.00           3.76
# 40                      baleno  2016           5.85           7.87
# 69               corolla altis  2016          14.25          20.91
# 80               corolla altis  2016          14.73          14.89
# 96                      innova  2016          20.75          25.39
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 108  Royal Enfield Thunder 350  2016           1.20           1.50
# 110                  KTM RC200  2016           1.20           1.78
# 111  Royal Enfield Thunder 350  2016           1.15           1.50
# ...

# %%
df_2016.to_excel('car-2016.xls')
df_2016.to_html('car-2016.html')

# %%
df[df['Selling_Price']>3.0]
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             ritz  2014           3.35           5.59       27000    Petrol
# 1              sx4  2013           4.75           9.54       43000    Diesel
# 2             ciaz  2017           7.25           9.85        6900    Petrol
# 4            swift  2014           4.60           6.87       42450    Diesel
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 296           city  2016           9.50          11.60       33988    Diesel
# 297           brio  2015           4.00           5.90       60000    Petrol
# 298           city  2009           3.35          11.00       87934    Petrol
# 299           city  2017          11.50          12.50        9000    Diesel
# 300           brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# ...

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df['Fuel_Type'].value_counts()
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
df[df['Fuel_Type']== 'CNG']
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 18  wagon r  2015           3.25           5.09       35500       CNG
# 35      sx4  2011           2.95           7.74       49998       CNG
#
#    Seller_Type Transmission  Owner
# 18      Dealer       Manual      0
# 35      Dealer       Manual      0

# %%
df['Transmission'].value_counts()
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
g = df.groupby('Year')
for i, j in g:
    print ('Year', i)
    print ('*********************')
    print (j.shape)
# Out:
# Year 2003
# *********************
# (2, 9)
# Year 2004
# *********************
# (1, 9)
# Year 2005
# *********************
# (4, 9)
# Year 2006
# *********************
# (4, 9)
# Year 2007
# *********************
# (2, 9)
# Year 2008
# *********************
# (7, 9)
# Year 2009
# *********************
# (6, 9)
# Year 2010
# *********************
# (15, 9)
# Year 2011
# *********************
# (19, 9)
# Year 2012
# *********************
# (23, 9)
# Year 2013
# *********************
# (33, 9)
# Year 2014
# *********************
# (38, 9)
# Year 2015
# *********************
# (61, 9)
# Year 2016
# *********************
# (50, 9)
# Year 2017
# *********************
# (35, 9)
# Year 2018
# *********************
# (1, 9)

# %%
df.isnull().sum() #missing values in my data
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
nr_cars = []
year= []
for i, j in g:
    year.append(i)
    nr_cars.append(j.shape[0])
print (nr_cars)
print (year)
print (len(year))
# Out:
# [2, 1, 4, 4, 2, 7, 6, 15, 19, 23, 33, 38, 61, 50, 35, 1]
# [2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
# 16

# %%
plt.pie(nr_cars, labels=year,autopct = '%1.2%%f')
plt.show()

# %%
plt.bar(year, nr_cars, color = 'blue')
# Out:
# <BarContainer object of 16 artists>

# %%
plt.bar(df['Year'],df['Present_Price'] , color = 'orange')
# Out:
# <BarContainer object of 301 artists>
